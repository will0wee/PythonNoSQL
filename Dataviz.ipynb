# %% [markdown]
# <a href="https://colab.research.google.com/github/will0wee/PythonNoSQL/blob/master/Dataviz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-dca536a9-79ec-4972-bd58-52ea1b46430e" name="files[]" multiple disabled />
#      <output id="result-dca536a9-79ec-4972-bd58-52ea1b46430e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving house_pricing.csv to house_pricing (1).csv

# %%
import pandas as pd
import matplotlib.pyplot as plt

col = "id = quantitative discrète, int\n"
col += "MSSubClass = quantitative discrète, int\n"
col += "MSZoning = qualitative, string\n"
col += "LotArea = quantitative discrète, int\n"
col += "Street = qualitative, string\n"
col += "Alley = qualitative, string\n"
col += "LotShape = qualitative, string\n"
col += "LandContour = qualitative, string\n"
##print(col)
##data.columns
data = pd.read_csv("house_pricing.csv")
data2 = data.query("LotArea < 20000 and SalePrice < 500000")
plt.scatter(data2.LotArea, data2.SalePrice)
plt.title('Taille du lot par rapport au prix de vente')
plt.xlabel('Taille de lot (inférieur à 20 000')
plt.ylabel('Prix de vente (inférieur à 500 000)')
plt.show()

data3 = data.query("LotFrontage < 200 and LotArea < 100000")
plt.scatter(data3.LotFrontage, data3.LotArea)
plt.title('Taille du lot par rapport au prix de vente')
plt.xlabel('Taille de la facade (inférieur à 200')
plt.ylabel('Taille du terrain (inférieur à 100 000)')
# Out:
# Text(0, 0.5, 'Taille du terrain (inférieur à 100 000)')
